# %%
import numpy as np
import pandas as pd
import requests
import os
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.dummy import DummyClassifier

# %%
os.getcwd()
# Out:
# '/home/dhanishtha/code/Dhanistha/holyniaina/facial-keypoints-detection/notebooks'

# %%
csv_path = os.path.join('..', 'raw_data', 'training.csv')
csv_path
# Out:
# '../raw_data/training.csv'

# %%
data = pd.read_csv(csv_path)
data
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 7044          67.402546          31.842551           29.746749
# 7045          66.134400          38.365501           30.478626
# 7046          66.690732          36.845221           31.666420
# 7047          70.965082          39.853666           30.543285
# 7048          66.938311          43.424510           31.096059
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
data.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# ...

# %%
len(data)
# Out:
# 7049

# %%
duplicate_count = len(data) - len(data.drop_duplicates()) # Original data length minus data length without duplicates
duplicate_count
# Out:
# 0

# %%
data.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7044    False
# 7045    False
# 7046    False
# 7047    False
# 7048    False
# Length: 7049, dtype: bool>

# %%
data.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        7039.000000        7039.000000         7036.000000
# mean           66.359021          37.651234           30.306102
# std             3.448233           3.152926            3.083230
# min            22.763345           1.616512            0.686592
# 25%            65.082895          35.900451           28.783339
# 50%            66.497566          37.528055           30.251378
# 75%            68.024752          39.258449           31.768334
# max            94.689280          80.502649           85.039381
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         7036.000000              2271.000000              2271.000000
# mean            37.976943                59.159339                37.944752
# std              3.033621                 2.690354                 2.307332
# min              4.091264                19.064954                27.190098
# ...

# %%
print(data.isnull())
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0                 False              False               False
# 1                 False              False               False
# 2                 False              False               False
# 3                 False              False               False
# 4                 False              False               False
# ...                 ...                ...                 ...
# 7044              False              False               False
# 7045              False              False               False
# 7046              False              False               False
# 7047              False              False               False
# 7048              False              False               False
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0                  False                    False                    False
# ...

# %%
print(data[data['left_eye_inner_corner_x'].isnull()])
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 1654          66.983855          37.191636           30.778167
# 1685          65.153204          39.850963           30.073522
# 1738          64.698292          41.840302           30.664127
# 1742          59.419060          39.825120           32.745235
# 1866                NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 7044          67.402546          31.842551           29.746749
# 7045          66.134400          38.365501           30.478626
# 7046          66.690732          36.845221           31.666420
# 7047          70.965082          39.853666           30.543285
# 7048          66.938311          43.424510           31.096059
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 1654           27.431834                      NaN                      NaN
# ...

# %% [markdown]
# ### Rows Having NaN Values

# %%
rows_having_nan_values = data[data.isnull().any(axis=1)]
print(rows_having_nan_values)
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 210           65.365120          39.988480           28.251520
# 350           67.258311          37.229867           26.980267
# 499           65.783008          41.160992           29.971041
# 512           68.286689          38.490807           31.361311
# 810           72.376354          37.281897           24.536920
# ...                 ...                ...                 ...
# 7044          67.402546          31.842551           29.746749
# 7045          66.134400          38.365501           30.478626
# 7046          66.690732          36.845221           31.666420
# 7047          70.965082          39.853666           30.543285
# 7048          66.938311          43.424510           31.096059
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 210            37.399680                59.322880                40.851840
# ...

# %% [markdown]
# ### Columns Having NaN Values

# %%
col_having_nan_values=data.loc[:, data.isnull().any()].columns
print(col_having_nan_values)
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'mouth_left_corner_x',
#        'mouth_left_corner_y', 'mouth_right_corner_x', 'mouth_right_corner_y',
#        'mouth_center_top_lip_x', 'mouth_center_top_lip_y',
#        'mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y'],
#       dtype='object')

# %% [markdown]
# ### Percentage of Missing Data in Column

# %%
percent_nan_in_each_col = data.isna().sum()/(len(data))*100
print(percent_nan_in_each_col)
# Out:
# left_eye_center_x            0.0
# left_eye_center_y            0.0
# right_eye_center_x           0.0
# right_eye_center_y           0.0
# left_eye_inner_corner_x      0.0
# left_eye_inner_corner_y      0.0
# left_eye_outer_corner_x      0.0
# left_eye_outer_corner_y      0.0
# right_eye_inner_corner_x     0.0
# right_eye_inner_corner_y     0.0
# right_eye_outer_corner_x     0.0
# right_eye_outer_corner_y     0.0
# left_eyebrow_inner_end_x     0.0
# left_eyebrow_inner_end_y     0.0
# left_eyebrow_outer_end_x     0.0
# left_eyebrow_outer_end_y     0.0
# right_eyebrow_inner_end_x    0.0
# right_eyebrow_inner_end_y    0.0
# right_eyebrow_outer_end_x    0.0
# right_eyebrow_outer_end_y    0.0
# nose_tip_x                   0.0
# nose_tip_y                   0.0
# mouth_left_corner_x          0.0
# mouth_left_corner_y          0.0
# mouth_right_corner_x         0.0
# mouth_right_corner_y         0.0
# mouth_center_top_lip_x       0.0
# mouth_center_top_lip_y       0.0
# ...

# %% [markdown]
# ### Number of NaN Values in Each Row with reference to column

# %%
no_nan_in_each_row=data.isna().sum(axis=1)
print(no_nan_in_each_row)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 7044    22
# 7045    22
# 7046    22
# 7047    22
# 7048    22
# Length: 7049, dtype: int64

# %% [markdown]
# ### Removing Rows Having Missing Data

# %%
# remove all rows that have atleast one missing value
data.dropna(inplace=True)

# remove all rows that have all values missing
data.dropna(how='all',inplace=True)

# %%
print(data)
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 2277          67.180378          35.816373           33.239956
# 2278          65.724490          36.301020           25.377551
# 2281          68.430866          38.651975           28.895857
# 2282          64.152180          30.691592           27.000898
# 2283          66.683755          34.483429           30.784490
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %% [markdown]
# ### Removing Columns Having Missing Data

# %%
# remove all columns that have atleast one missing value
data.dropna(axis='columns',inplace=True)

# remove all columns that have all values missing
data.dropna(axis='columns',how='all',inplace=True)

# %% [markdown]
# # Replace Missing Data with Fixed Values in dataFrame

# %%
data.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        2140.000000        2140.000000         2140.000000
# mean           66.221549          36.842274           29.640269
# std             2.087683           2.294027            2.051575
# min            47.835757          23.832996           18.922611
# 25%            65.046300          35.468842           28.472224
# 50%            66.129065          36.913319           29.655440
# 75%            67.332093          38.286438           30.858673
# max            78.013082          46.132421           42.495172
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         2140.000000              2140.000000              2140.000000
# mean            37.063815                59.272128                37.856014
# std              2.234334                 2.005631                 2.034500
# min             24.773072                41.779381                27.190098
# ...

# %% [markdown]
# ### Replace Missing Data with Mean Value

# %%
# Replace all NaN value of Column 'left_eye_inner_corner_x' by Average of all points
#mean_value =data['left_eye_inner_corner_x'].mean()
#data['left_eye_inner_corner_x'].fillna(mean_value,inplace=True)
#print(data)

# %%
# Replace all NaN value of Column 'left_eye_inner_corner_y' by Average of all points
#mean_value =data['left_eye_inner_corner_y'].mean()
#data['left_eye_inner_corner_y'].fillna(mean_value,inplace=True)
#print(data)

# %% [markdown]
# ## KNN Model
